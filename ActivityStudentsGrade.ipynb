# %% [markdown]
# <a href="https://colab.research.google.com/github/PikuFuka/CSEL-302-comp/blob/main/ActivityStudentsGrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import libraries**

# %%
import pandas as pd #Data manipulation
import numpy as np #Numerical Operation
import matplotlib.pyplot as plt #Data Visualization
from sklearn.linear_model import LinearRegression #Data modeling

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset.csv')
data.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %%
plt.scatter(data['Previous_Exam_Scores'], data['Grades'])
plt.xlabel('Independent Variable (X)')
plt.xlabel('Dependent Variable (Y)')
plt.title('Student')
plt.show()

# %%
X = data[['Previous_Exam_Scores']] #Independent Varibles
Y = data[['Grades']] #Dependent Varibles

# %%
model = LinearRegression()

model.fit(X, Y)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]

intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)
# Out:
# Slope [0.2556363]
# Intercept [16.98814303]

# %%
plt.scatter(X, Y)
plt.plot(X, model.predict(X), color = 'RED')
plt.xlabel('Independent variable (X)')
plt.ylabel('Dependent variable (Y)')
plt.title('Linear Regression')
plt.show()

# %%
new_X = [[np.random.randint(0, 100)]]

predicted_Y = model.predict(new_X)

print('Value of X', new_X)
print('Predicted Value of Y', predicted_Y)
# Out:
# Value of X [[99]]
# Predicted Value of Y [[42.29613647]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
